# %%
import pandas as pd

data = pd.read_csv('children anemia.csv')

data = data.dropna()
data
# Out:
#       Age in 5-year groups Type of place of residence  \
# 3                    25-29                      Urban
# 6                    35-39                      Urban
# 9                    20-24                      Urban
# 12                   25-29                      Urban
# 13                   20-24                      Urban
# ...                    ...                        ...
# 33914                25-29                      Rural
# 33917                25-29                      Rural
# 33918                35-39                      Rural
# 33921                25-29                      Rural
# 33922                20-24                      Rural
#
#       Highest educational level Wealth index combined  \
# 3                     Secondary               Richest
# 6                     Secondary               Richest
# 9                     Secondary               Richest
# 12                       Higher               Richest
# ...

# %%
import pandas as pd

data = pd.read_csv('children anemia.csv')

data['Births in last five years'].fillna(data['Births in last five years'].mean(), inplace=True)
data
# Out:
#       Age in 5-year groups Type of place of residence  \
# 0                    40-44                      Urban
# 1                    35-39                      Urban
# 2                    25-29                      Urban
# 3                    25-29                      Urban
# 4                    20-24                      Urban
# ...                    ...                        ...
# 33919                35-39                      Rural
# 33920                25-29                      Rural
# 33921                25-29                      Rural
# 33922                20-24                      Rural
# 33923                40-44                      Rural
#
#       Highest educational level Wealth index combined  \
# 0                        Higher               Richest
# 1                        Higher               Richest
# 2                        Higher               Richest
# 3                     Secondary               Richest
# ...

# %%
import pandas as pd

data = pd.read_csv('children anemia.csv')

data = pd.get_dummies(data, columns=['Anemia level'])
data
# Out:
#       Age in 5-year groups Type of place of residence  \
# 0                    40-44                      Urban
# 1                    35-39                      Urban
# 2                    25-29                      Urban
# 3                    25-29                      Urban
# 4                    20-24                      Urban
# ...                    ...                        ...
# 33919                35-39                      Rural
# 33920                25-29                      Rural
# 33921                25-29                      Rural
# 33922                20-24                      Rural
# 33923                40-44                      Rural
#
#       Highest educational level Wealth index combined  \
# 0                        Higher               Richest
# 1                        Higher               Richest
# 2                        Higher               Richest
# 3                     Secondary               Richest
# ...

# %%
import pandas as pd
data = pd.read_csv('children anemia.csv')
print(data.head())
print(data.head())
total_births = data['Births in last five years'].sum()
print(f"Total births: ${total_births}")
# Out:
#   Age in 5-year groups Type of place of residence Highest educational level  \
# 0                40-44                      Urban                    Higher
# 1                35-39                      Urban                    Higher
# 2                25-29                      Urban                    Higher
# 3                25-29                      Urban                 Secondary
# 4                20-24                      Urban                 Secondary
#
#   Wealth index combined  Births in last five years  \
# 0               Richest                          1
# 1               Richest                          1
# 2               Richest                          1
# 3               Richest                          1
# 4               Richest                          1
#
#    Age of respondent at 1st birth  \
# 0                              22
# 1                              28
# 2                              26
# 3                              25
# ...
